# %%
#!/usr/bin/env python3
# monthly_avg_loader.py  –  add MONTHLY_AVG_LOAD once per feeder
# -------------------------------------------------------------
#  • Reads consolidated feeder file (with FEEDER_ID column)
#  • Scans all CSVs in data_folders
#      – UTF-8 → Latin-1 fallback
#      – skips rows with broken quotes, etc.
#      – keeps only PARA == 'I'
#  • SWNO == FEEDER_ID match
#  • Averages VALUE month-wise → overall monthly average
#  • Writes that number in first row for each feeder
#  • Saves final_with_monthly_avg.csv

from __future__ import annotations
import pandas as pd
from pathlib import Path
from glob import glob

# ── paths ────────────────────────────────────────────────────────
CONSOLIDATED_CSV = "final_two_column_with_rank_11_withoutDT.csv"

DATA_FOLDERS = [
    "/media/sagarkumar/New Volume/SAGAR/200/200",
    "/media/sagarkumar/New Volume/SAGAR/200-400/200-400",
    "/media/sagarkumar/New Volume/SAGAR/400-600/400-600",
    "/media/sagarkumar/New Volume/SAGAR/600-759/600-759",
]

OUTPUT_CSV = "final_with_monthly_avg.csv"

# ── 1. consolidated feeder table ────────────────────────────────
feeder_df = pd.read_csv(CONSOLIDATED_CSV)
feeder_df["FEEDER_ID"] = feeder_df["FEEDER_ID"].astype(str)

# ── 2. load all CSVs with encoding + parser fallback ─────────────
needed = {"SWNO", "PARA", "VALUE", "SYSTIME"}
frames = []

for folder in DATA_FOLDERS:
    for csv_path in glob(str(Path(folder) / "*.csv")):
        loaded = None
        for enc in ("utf-8", "latin-1"):
            for engine in ("c", "python"):
                try:
                    print(f"Loading {csv_path} with encoding {enc} and engine {engine}...")
                    loaded = pd.read_csv(
                        csv_path,
                        low_memory=False,
                        usecols=lambda c: c.upper() in needed,
                        encoding=enc,
                       
                        on_bad_lines="skip",   # drop malformed rows
                    )
                    break
                except (UnicodeDecodeError, pd.errors.ParserError):
                    continue
            if loaded is not None:
                break
        if loaded is None:
            print(f"⚠️  skipped (decode/parse errors): {csv_path}")
            continue
        if "PARA" not in loaded.columns:
            continue

        mask = loaded["PARA"].str.upper() == "I"
        frames.append(loaded.loc[mask, ["SWNO", "VALUE", "SYSTIME"]])

if not frames:
    raise RuntimeError("No usable load rows (PARA == 'I') found in folders.")

load = pd.concat(frames, ignore_index=True)
load["SWNO"] = load["SWNO"].astype(str)
load["SYSTIME"] = pd.to_datetime(load["SYSTIME"], errors="coerce", utc=True)
load = load.dropna(subset=["SYSTIME"])

# ── 3. monthly means → overall average per feeder ───────────────
load["YEAR_MONTH"] = load["SYSTIME"].dt.to_period("M")

month_means = (
    load.groupby(["SWNO", "YEAR_MONTH"])["VALUE"]
        .mean()
        .reset_index()
)

overall_avg = (
    month_means.groupby("SWNO")["VALUE"]
        .mean()
        .reset_index()
        .rename(columns={"SWNO": "FEEDER_ID",
                         "VALUE": "MONTHLY_AVG_LOAD"})
)

overall_avg["FEEDER_ID"] = overall_avg["FEEDER_ID"].astype(str)

# ── 4. merge → write once per feeder ────────────────────────────
merged = feeder_df.merge(overall_avg, how="left", on="FEEDER_ID")

merged["MONTHLY_AVG_LOAD"] = (
    merged.groupby("FEEDER_ID")["MONTHLY_AVG_LOAD"]
          .transform(lambda s: [s.iat[0]] + [pd.NA] * (len(s) - 1))
)

# ── 5. export ────────────────────────────────────────────────────
merged.to_csv(OUTPUT_CSV, index=False)
print(f"Saved {len(merged):,} rows → {OUTPUT_CSV}")
# Out:
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000182.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000183.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000184.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000185.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000186.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000187.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000188.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000189.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000190.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000191.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000192.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000193.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000194.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000195.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000196.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000197.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000198.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000199.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000000.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000001.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000002.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000003.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000004.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000005.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000006.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000007.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000008.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000009.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000010.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000010.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000010.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000011.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000013.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000014.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000014.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000014.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000014.csv with encoding latin-1 and engine python...
# ⚠️  skipped (decode/parse errors): /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000014.csv
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000015.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000016.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000016.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000016.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000017.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000017.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000017.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000018.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000019.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000019.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000019.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000020.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000021.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000022.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000022.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000022.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000023.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000024.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000024.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000024.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000026.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000027.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000028.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000028.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000028.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000029.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000030.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000030.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000030.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000031.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000032.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000033.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000034.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000034.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000034.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000035.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000035.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000035.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000036.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000037.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000012.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000025.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000025.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000025.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000038.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000051.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000064.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000077.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000090.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000090.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000090.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000103.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000116.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000116.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000116.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000129.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000142.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000155.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000168.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000168.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000168.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000181.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000039.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000040.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000041.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000042.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000043.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000044.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000045.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000046.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000047.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000048.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000049.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000050.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000052.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000053.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000054.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000054.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000054.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000055.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000056.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000057.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000058.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000059.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000060.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000061.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000062.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000063.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000065.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000066.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000067.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000068.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000069.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000070.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000070.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000070.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000071.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000071.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000071.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000072.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000073.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000073.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000073.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000074.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000075.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000076.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000078.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000079.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000079.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000079.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000080.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000081.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000082.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000083.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000084.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000085.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000086.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000087.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000088.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000089.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000089.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000089.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000091.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000092.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000093.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000094.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000094.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000094.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000095.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000096.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000097.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000098.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000099.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000100.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000101.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000102.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000104.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000105.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000106.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000107.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000108.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000109.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000110.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000111.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000112.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000113.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000113.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000113.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000114.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000115.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000117.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000118.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000119.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000120.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000121.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000122.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000122.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000122.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000123.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000124.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000125.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000126.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000127.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000128.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000130.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000131.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000131.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000131.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000132.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000133.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000134.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000134.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000134.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000135.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000136.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000136.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000136.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000137.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000138.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000139.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000139.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000139.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000140.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000141.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000143.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000144.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000145.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000146.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000147.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000148.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000149.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000150.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000151.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000152.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000153.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000154.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000154.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000154.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000156.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000157.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000158.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000159.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000160.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000161.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000162.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000163.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000164.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000165.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000166.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000167.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000169.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000170.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000171.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000172.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000173.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000173.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000173.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000174.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000175.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000176.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000177.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000178.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000179.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000180.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000200.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000201.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000202.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000203.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000204.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000205.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000206.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000207.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000207.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000207.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000208.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000209.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000210.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000211.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000212.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000214.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000215.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000216.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000217.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000217.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000217.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000218.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000219.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000220.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000221.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000222.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000223.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000224.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000225.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000226.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000228.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000229.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000230.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000231.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000232.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000233.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000234.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000235.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000236.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000237.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000238.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000239.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000240.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000242.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000243.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000244.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000245.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000246.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000247.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000248.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000249.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000250.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000251.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000252.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000253.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000254.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000213.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000227.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000241.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000255.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000269.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000283.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000298.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000312.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000326.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000340.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000354.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000368.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000382.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000256.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000257.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000258.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000259.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000260.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000261.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000262.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000263.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000264.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000265.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000266.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000267.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000268.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000270.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000271.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000272.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000273.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000274.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000275.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000276.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000277.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000278.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000279.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000280.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000281.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000282.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000284.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000286.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000287.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000288.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000289.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000289.csv with encoding utf-8 and engine python...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000289.csv with encoding latin-1 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000290.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000291.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000292.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000293.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000294.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000295.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000296.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000297.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000299.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000300.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000301.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000302.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000303.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000304.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000305.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000306.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000307.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000308.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000309.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000310.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000311.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000313.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000314.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000315.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000316.csv with encoding utf-8 and engine c...
# ...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000586.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000587.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000588.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000589.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000590.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000591.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000592.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000593.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000594.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000595.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000596.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000597.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000598.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000599.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000743.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000744.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000745.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000746.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000747.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000748.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000749.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000750.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000751.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000752.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000753.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000754.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000755.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000756.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000757.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000758.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000600.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000601.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000602.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000603.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000604.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000605.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000606.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000607.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000608.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000609.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000610.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000611.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000613.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000614.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000615.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000616.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000617.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000618.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000619.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000620.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000621.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000622.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000623.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000624.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000626.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000627.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000628.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000629.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000630.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000631.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000632.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000633.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000634.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000635.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000636.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000637.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000612.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000625.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000638.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000651.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000664.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000677.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000690.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000703.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000716.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000729.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000742.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000639.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000640.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000641.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000642.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000643.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000644.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000645.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000646.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000647.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000648.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000649.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000650.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000652.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000653.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000654.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000655.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000656.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000657.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000658.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000659.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000660.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000661.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000662.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000663.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000665.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000666.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000667.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000668.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000669.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000670.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000671.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000672.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000673.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000674.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000675.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000676.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000678.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000679.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000680.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000681.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000682.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000683.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000684.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000685.csv with encoding utf-8 and engine c...
# Loading /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000686.csv with encoding utf-8 and engine c...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
from pathlib import Path
import multiprocessing as mp

# Update these paths
feeder_file = "/media/sagarkumar/New Volume/SAGAR/IPYNB_FILE/feeder_ids_list_11.csv"  # This is your input file with FEEDERID column
output_file = "scada_dara_matched_with_feeder.csv"

data_folders = [
    "/media/sagarkumar/New Volume/SAGAR/200/200",
    "/media/sagarkumar/New Volume/SAGAR/200-400/200-400",
    "/media/sagarkumar/New Volume/SAGAR/400-600/400-600",
    "/media/sagarkumar/New Volume/SAGAR/600-759/600-759",
]

# Step 1: Load FEEDERIDs as a set of strings (for fast matching)
feeder_ids = pd.read_csv(feeder_file, dtype=str)['FEEDER'].dropna().astype(str).unique().tolist()
feeder_ids_set = set(feeder_ids)

def process_file(file):
    try:
        matches = []
        for chunk in pd.read_csv(file, chunksize=200_000, dtype=str, encoding='utf-8', engine='python', on_bad_lines='skip'):
            filtered = chunk[chunk['SWNO'].astype(str).isin(feeder_ids_set)]
            if not filtered.empty:
                matches.append(filtered)
        if matches:
            return pd.concat(matches, ignore_index=True)
    except Exception as e:
        print(f"{file} skipped: {e}")
    return None

if __name__ == '__main__':
    # Step 2: Collect all csv files
    all_files = []
    for folder in data_folders:
        all_files.extend(Path(folder).glob("*.csv"))

    # Step 3: Multiprocessing for fast parallel reads
    with mp.Pool(mp.cpu_count()) as pool:
        results = pool.map(process_file, all_files)

    # Step 4: Combine results, add FEEDERID column, and sort
    dfs = [df for df in results if df is not None and not df.empty]
    if dfs:
        final_df = pd.concat(dfs, ignore_index=True)
        # Merge to add the FEEDERID column (optional, if you want to keep the mapping)
        final_df = final_df.merge(
            pd.DataFrame({'FEEDERID': feeder_ids}),
            left_on='SWNO', right_on='FEEDERID', how='left'
        )
        final_df = final_df.sort_values('FEEDERID')
        final_df.to_csv(output_file, index=False)
        print(f"Matched and sorted rows saved to {output_file}")
    else:
        print("No matches found.")
# Out:
# /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000231.csv skipped: line contains NUL
# /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000233.csv skipped: line contains NUL
# /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000410.csv skipped: 'utf-8' codec can't decode byte 0xe6 in position 4099: invalid continuation byte
# free(): invalid pointer
# /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000414.csv skipped: 'utf-8' codec can't decode byte 0xc8 in position 4099: invalid continuation byte
# /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000415.csv skipped: 'utf-8' codec can't decode byte 0xe9 in position 3: invalid continuation byte
