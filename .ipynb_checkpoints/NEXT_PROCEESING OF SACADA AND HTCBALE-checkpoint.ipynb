# %%
import pandas as pd
from pathlib import Path
import multiprocessing as mp

data_folders = [
    "/media/sagarkumar/New Volume/SAGAR/200/200",
    "/media/sagarkumar/New Volume/SAGAR/200-400/200-400",
    "/media/sagarkumar/New Volume/SAGAR/400-600/400-600",
    "/media/sagarkumar/New Volume/SAGAR/600-759/600-759",
]

# ──────────────────────────────────────────────────────────
# build the flat list of CSV paths
# ──────────────────────────────────────────────────────────
csv_files = [p for folder in data_folders
               for p in Path(folder).glob("*.csv")
               if Path(folder).is_dir()]

# %%
import gc

# Create sets to hold unique PARA and VOLTAGE values
unique_para = set()
unique_voltage = set()


for folder in data_folders:
    folder_path = Path(folder)
    for csv_path in folder_path.glob("*.csv"):
        try:
            df = pd.read_csv(csv_path, dtype=str, low_memory=False)

            if "PARA" in df.columns:
                unique_para.update(df["PARA"].dropna().unique())
                print(f"Processed {csv_path} for PARA values.")
            if "VOLTAGE" in df.columns:
                unique_voltage.update(df["VOLTAGE"].dropna().unique())
              
        except Exception as e:
            print(f"Error reading {csv_path}: {e}")
     

print("Unique PARA values:")
print(unique_para)
print("\nUnique VOLTAGE values:")
print(unique_voltage)
# Out:
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000182.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000183.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000184.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000185.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000186.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000187.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000188.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000189.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000190.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000191.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000192.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000193.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000194.csv: 'utf-8' codec can't decode byte 0xc3 in position 36067: invalid continuation byte
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000195.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000196.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000197.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000198.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000199.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000000.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000001.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000002.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000003.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000004.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000005.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000006.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000007.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000008.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000009.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000010.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000011.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000013.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000014.csv: Error tokenizing data. C error: EOF inside string starting at row 372467
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000015.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000016.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000017.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000018.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000019.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000020.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000021.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000022.csv: 'utf-8' codec can't decode byte 0xb2 in position 134163: invalid start byte
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000023.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000024.csv: 'utf-8' codec can't decode byte 0xfb in position 192547: invalid start byte
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000026.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000027.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000028.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000029.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000030.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000031.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000032.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000033.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000034.csv: 'utf-8' codec can't decode byte 0xa5 in position 163843: invalid start byte
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000035.csv: Error tokenizing data. C error: Expected 10 fields in line 51897, saw 13
#
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000036.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000037.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000012.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000025.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000038.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000051.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000064.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000077.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000090.csv: 'utf-8' codec can't decode byte 0xc8 in position 61443: invalid continuation byte
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000103.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000116.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000129.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000142.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000155.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000168.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000181.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000039.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000040.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000041.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000042.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000043.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000044.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000045.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000046.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000047.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000048.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000049.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000050.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000052.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000053.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000054.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000055.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000056.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000057.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000058.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000059.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000060.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000061.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000062.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000063.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000065.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000066.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000067.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000068.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000069.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000070.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000071.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000072.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000073.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000074.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000075.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000076.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000078.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000079.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000080.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000081.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000082.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000083.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000084.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000085.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000086.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000087.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000088.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000089.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000091.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000092.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000093.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000094.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000095.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000096.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000097.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000098.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000099.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000100.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000101.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000102.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000104.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000105.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000106.csv: 'utf-8' codec can't decode byte 0xb6 in position 53251: invalid start byte
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000107.csv: 'utf-8' codec can't decode byte 0x98 in position 258051: invalid start byte
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000108.csv: 'utf-8' codec can't decode byte 0xf5 in position 45059: invalid start byte
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000109.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000110.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000111.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000000112.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/200/200/2025-05-07_SCADA000000
csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000396.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000397.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000398.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/200-400/200-400/2025-05-07_SCADA000000000399.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000400.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000401.csv: 'utf-8' codec can't decode byte 0xb3 in position 76803: invalid start byte
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000402.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000403.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000404.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000405.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000406.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000407.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000408.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000409.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000410.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000411.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000412.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000414.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000415.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000416.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000417.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000418.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000419.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000420.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000421.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000422.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000423.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000424.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000425.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000426.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000428.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000429.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000430.csv: 'utf-8' codec can't decode byte 0xb6 in position 245891: invalid start byte
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000431.csv for PARA values.
# Error reading /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000432.csv: 'utf-8' codec can't decode byte 0xa9 in position 133747: invalid start byte
# Processed /media/sagarkumar/New Volume/SAGAR/400-600/400-600/2025-05-07_SCADA000000000433.csv for PARA values.
# ...
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000603.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000604.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000605.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000606.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000607.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000608.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000609.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000610.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000611.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000613.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000614.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000615.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000616.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000617.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000618.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000619.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000620.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000621.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000622.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000623.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000624.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000626.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000627.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000628.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000629.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000630.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000631.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000632.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000633.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000634.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000635.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000636.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000637.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000612.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000625.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000638.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000651.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000664.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000677.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000690.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000703.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000716.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000729.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000742.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000639.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000640.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000641.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000642.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000643.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000644.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000645.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000646.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000647.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000648.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000649.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000650.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000652.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000653.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000654.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000655.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000656.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000657.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000658.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000659.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000660.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000661.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000662.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000663.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000665.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000666.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000667.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000668.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000669.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000670.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000671.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000672.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000673.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000674.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000675.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000676.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000678.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000679.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000680.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000681.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000682.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000683.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000684.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000685.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000686.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000687.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000688.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000689.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000691.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000692.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000693.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000694.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000695.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000696.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000697.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000698.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000699.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000700.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000701.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000702.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000704.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000705.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000706.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000707.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000708.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000709.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000710.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000711.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000712.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000713.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000714.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000715.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000717.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000718.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000719.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000720.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000721.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000722.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000723.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000724.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000725.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000726.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000727.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000728.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000730.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000731.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000732.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000733.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000734.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000735.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000736.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000737.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000738.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000739.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000740.csv for PARA values.
# Processed /media/sagarkumar/New Volume/SAGAR/600-759/600-759/2025-05-07_SCADA000000000741.csv for PARA values.
# Unique PARA values:
# {'0.9927502', '32.96', '661.86', 'v', 'oVA', '0', '%VA', '\\VA', '33\x0c76600024-be5b-4(e2-a585-55fe953da02f', '32.508934', 'KW', 'PF', 'Temp', 'I', 'K\x17', 'PF(0.9927502', 'MVA', '-0.982666', '-3062.173:281', 'V', 'E'}
#
# Unique VOLTAGE values:
# {'33KV', '11)V', '22KV', 'KW', 'PF', '11', '33KT', '51KV', 'V', 'I', '33', '14', '11(PF', 'MVA', '22', '11KV', '\x1f1KV', 'r2'}

# %%
# load the master list of SWNO values
import pandas as pd
df_all = pd.read_csv('/media/sagarkumar/New Volume/SAGAR/all_unique_SWNO.csv', dtype=str)


# load the per-file SWNO list (each row contains semicolon-separated SWNO strings)
df_each = pd.read_csv('/media/sagarkumar/New Volume/SAGAR/IPYNB_FILE/final_two_column_with_rank_11_withoutDT.csv')
set_feeder = set(df_each["FEEDER_ID"].dropna().unique())

# %%
df_each["feeder_match"] = df_all["SWNO"].isin(set_feeder)

print(f"Rows with matching FEEDER_ID: {df_each['feeder_match'].sum()}")
# Out:
# Rows with matching FEEDER_ID: 1091

# %%
len(df_each["FEEDER_ID"].unique())
# Out:
# 1100

# %% [markdown]
# USING PANDAS

# %%
import pandas as pd
from pathlib import Path
import concurrent.futures
import os

# List of folders containing the CSV files
data_folders = [
    "/media/sagarkumar/New Volume/SAGAR/200/200",
    "/media/sagarkumar/New Volume/SAGAR/200-400/200-400",
    "/media/sagarkumar/New Volume/SAGAR/400-600/400-600",
    "/media/sagarkumar/New Volume/SAGAR/600-759/600-759",
]

# --- Configuration ---
# The name of the column that contains the switch numbers.
SWNO_COLUMN_NAME = 'SWNO'

# Path for the output file
output_file = "/media/sagarkumar/New Volume/SAGAR/unique_swno_faster.csv"


def process_file(file_path):
    """
    Worker function to be run in parallel.
    Reads a single CSV file and returns a set of unique 'swno' values.
    """
    try:
        # Use pandas to read only the specific column. This is memory-efficient.
        df = pd.read_csv(file_path, usecols=[SWNO_COLUMN_NAME], on_bad_lines='skip', engine='c',low_memeory = False)
        
        # Return a set of unique, non-null values from the column
        return set(df[SWNO_COLUMN_NAME].dropna().unique())
    except ValueError:
        # This error happens if the SWNO_COLUMN_NAME is not in the CSV
        print(f"Warning: Column '{SWNO_COLUMN_NAME}' not found in {file_path.name}. Skipping file.")
    except Exception as e:
        # Catch any other potential errors during file processing
        print(f"Error processing file {file_path.name}: {e}")
    # Return an empty set if there was an error or no values were found
    return set()


if __name__ == "__main__":
    print("Gathering all CSV file paths...")
    # First, collect a list of all files to be processed.
    all_files_to_process = []
    for folder_path in data_folders:
        folder = Path(folder_path)
        if folder.is_dir():
            all_files_to_process.extend(list(folder.glob('*.csv')))
        else:
            print(f"Warning: Folder not found at {folder_path}. Skipping.")
    
    if not all_files_to_process:
        print("No CSV files found to process. Exiting.")
    else:
        print(f"Found {len(all_files_to_process)} total files. Starting parallel processing...")
        
        # This master set will hold all unique values from all files
        master_unique_swno_set = set()

        # Use ProcessPoolExecutor to run the 'process_file' function in parallel
        # It will automatically use the available CPU cores
        with concurrent.futures.ProcessPoolExecutor() as executor:
            # map() applies the function to each item in the list and returns results as they complete
            results = executor.map(process_file, all_files_to_process)
            
            # As each worker process finishes, its resulting set is merged into the master set
            for unique_set in results:
                if unique_set: # Ensure the set is not empty
                    master_unique_swno_set.update(unique_set)

        print("\nAll files processed. Consolidating and saving results...")

        # Convert the final set of unique values to a DataFrame
        unique_df = pd.DataFrame(list(master_unique_swno_set), columns=[SWNO_COLUMN_NAME])
        
        # Sort the values for cleaner output
        unique_df = unique_df.sort_values(by=SWNO_COLUMN_NAME).reset_index(drop=True)

        # Save the DataFrame to the specified output CSV file
        try:
            unique_df.to_csv(output_file, index=False)
            print(f"\n✅ Success! All unique 'swno' values have been saved to:")
            print(output_file)
            print(f"Total unique values found: {len(unique_df)}")
        except Exception as e:
            print(f"\n❌ Error: Could not save the output file. Reason: {e}")
